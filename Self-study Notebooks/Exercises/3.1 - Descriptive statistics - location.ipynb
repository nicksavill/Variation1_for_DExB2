# %% [markdown]
# ### Exercise 3.1.1
# <br>
# <div>
# <img src="attachment:bee.jpg" title="Muhammad Mahdi Karim - Own work
# 12mm long Apis mellifera, Apis mellifera. Pictured in Dar es Salaam, Tanzania."/>
# </div>
#
# Researchers recorded the foraging lifespan in hours of 33 worker bees.
#
# 1. Import the pandas and seaborn modules.
# 2. Read in the csv file `Datasets/bee lifespans.csv` into a pandas DataFrame called `bees`.
# 3. Plot a histogram of `bees['hours']` and add some useful annotation.
# 4. Estimate the mean foraging lifespan by eye-balling the histogram.

# %%
import pandas as pd
import seaborn as sns

bees = pd.read_csv('Datasets/bee lifespans.csv')

g = sns.displot(bees['hours'])

g.ax.set_xlabel('Foraging lifespan (hour)')
g.ax.set_ylabel('Number of bees')
g.ax.set_title('Foraging lifespan of 33 worker bees');

# %% [markdown]
# ### Exercise 3.1.2
#
# 1. Using pandas, calculate the mean foraging lifespan of the bees to the appropriate number of decimal places.
# 2. Was your estimate of the mean close to the actual mean?
#
# <div class="alert alert-info">
# Your answer should be 27.85 hours.
# </div>

# %%
xbar = bees.mean()

print(f"mean foraging lifespan is {xbar['hours']:.2f} hours")

# %% [markdown]
# ### Exercise 3.1.3
# <br>
# <div>
# <img src="attachment:Elephant_sea_fight.jpg" width='50%' title="Mike Baird CC 2.0"/>
# </div>
#
# Elephant seals defend harems that may contain hundreds of reproductively active females. Researchers recorded the numbers of females in harems in a population on South Georgia Island.
#
# 1. Import the pandas module and seaborn modules.
# 2. Read in the csv file `Datasets/elephant seal.csv` into a pandas DataFrame called `seal`.
# 3. Plot a histogram of `seal['Harem size']` and add some useful annotation.
# 4. Estimate the mean harem size by eye-balling the histogram.

# %%
import pandas as pd
import seaborn as sns

seal = pd.read_csv('Datasets/elephant seal.csv')

g = sns.displot(seal['Harem size'])

g.ax.set_ylabel('Number of harems')
g.ax.set_title('Harem size of elephant seals on South Georgia Island');

# %% [markdown]
# ### Exercise 3.1.4
#
# 1. Using pandas, calculate the mean harem size to the appropriate number of decimal places.
# 2. Was your estimate of the mean close to the actual mean?
#
# <div class="alert alert-info">
# Your answer should be 40.0 females.
# </div>

# %%
xbar = seal.mean()

print(f"mean harem size is {xbar['Harem size']:.1f}")

# %% [markdown]
# ## Next Notebook

# %% [markdown]
# [Descriptive statistics: spread](../3.2%20-%20Descriptive%20statistics%20-%20spread.ipynb)
